# %%
import networkx as nx 
import matplotlib.pyplot as plt
G=nx.DiGraph() 

G.add_edge('UU Nomor 26 Tahun 2000','UUD 1945') 
G.add_edge('UU Nomor 26 Tahun 2000','UU Nomor 14 Tahun 1970') 
G.add_edge('UU Nomor 40 Tahun 1999','UU Nomor 2 Tahun 1986')
G.add_edge('UU Nomor 40 Tahun 1999','UU Nomor 39 Tahun 1999')


G.add_edge('UU Nomor 35 Tahun 2014','UUD')
G.add_edge('UU Nomor 35 Tahun 2014','UU Nomor 23 Tahun 2002')
G.add_edge('UU Nomor 35 Tahun 2014','UU Nomor 11 Tahun 2012')

G.add_edge('UU Nomor 39 Tahun 1999','UUD 1945')
G.add_edge('UU Nomor 39 Tahun 1999','Ketetapan MPR Nomor XVII/MPR/1998')

G.add_edge('UU Nomor 39 Tahun 2014','UUD 1945')

G.add_edge('UU Nomor 40 Tahun 2014','UUD 1945')

G.add_edge('UU Nomor 43 Tahun 2014','UUD 1945')

G.add_edge('UU Nomor 51 Tahun 2009','UUD 1945')

G.add_edge('UU Nomor 5 Tahun 2018','UUD 1945')
G.add_edge('UU Nomor 5 Tahun 2018','UU Nomor 15 Tahun 2003')

G.add_edge('UU Nomor 6 Tahun 2018','UUD 1945')

G.add_edge('UU Nomor 23 Tahun 2018','UUD 1945')


nx.draw_networkx(G)
plt.axis('off')
plt.show() # display
